# %% [markdown]
# # 회귀분석
# * 지도학습
# * 종속변수(target) 변수가 수치형 자료
# * 집값, 보험료, 몸무게와 같이 연속적인 숫자로 이루어진 값을 예측
# * 회귀 => 평균으로 돌아간다

# %% [markdown]
# 단순 선형 회귀분석 / 다중 선형 회귀분석
# * 단순 선형 회귀분석: 독립변수1, 종속변수1
# * 다중 선형 회귀분석: 독립변수n, 종속변수 1

# %% [markdown]
# 1. 단순 회귀 분석: 자동차 배기량과 연비 회귀 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import koreanize_matplotlib

# %%
# X는 자동차 배기량, y는 연비
X = np.array([1, 1.4, 1.6, 2, 2.2, 2.4, 3, 3.3, 3.6])
y = np.array([15, 13, 13, 12, 11, 10.5, 10, 9, 8])


# 상수 추가 y 절편 추가
X_with_const = sm.add_constant(X)

# 모델 훈련
model = sm.OLS(y, X_with_const).fit()
y_pred = model.predict(X_with_const)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                     203.7
# Date:                Wed, 07 May 2025   Prob (F-statistic):           1.97e-06
# Time:                        14:13:26   Log-Likelihood:                -3.9965
# No. Observations:                   9   AIC:                             11.99
# Df Residuals:                       7   BIC:                             12.39
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.8291      0.414     40.626      0.000      15.850      17.809
# x1            -2.4371      0.171    -14.273      0.000      -2.841      -2.033
# ==============================================================================
# Omnibus:                        0.845   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.656   Jarque-Bera (JB):                0.585
# Skew:                           0.128   Prob(JB):                        0.746
# Kurtosis:                       1.778   Cond. No.                         8.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\vbak0\miniforge3\envs\fintech\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   res = hypotest_fun_out(*samples, **kwds)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred)
plt.title("단순 선형 회귀분석, 엔진 배기량과 연비의 관계")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# * R-squared: 0.967로 약 96%를 설명한다
# * p-value: 1.97e-06으로 매우 작다 (0.0001이하, 0.05) 통계적으로 유의미
# * X1의 회귀계수(coefficient-coef)는 -2.4371
# * y절편(상수항)은 16.8291
# * 따라서 추정되는 회귀식은 y(연비) = -2.4371 * X1 + 16.8291

# %% [markdown]
# # 다중 회귀 분석
# * 독립변수가 여러 개인 데이터

# %%
# 데이터
yard = np.array([31, 31, 27, 39, 30, 32, 28, 23, 28, 35])
area = np.array([58, 51, 47, 35, 48, 42, 43, 56, 41, 41])
park = np.array([1, 1, 5, 5, 2, 4, 5, 1, 1, 3])
dist = np.array([492, 426, 400, 125, 443, 412, 201, 362, 192, 423])
price = np.array([12631, 12084, 12220, 11486, 12276, 15527, 12666, 13180, 10169])

# %%
# 독립 변수와 종속 변수 설정
X = pd.DataFrame(dict(yard=yard, area=area, park=park, dist=dist))
y = price

# %%
X = sm.add_constant(X)
X
# Out:
#    const  yard  area  park  dist
# 0    1.0    31    58     1   492
# 1    1.0    31    51     1   426
# 2    1.0    27    47     5   400
# 3    1.0    39    35     5   125
# 4    1.0    30    48     2   443
# 5    1.0    32    42     4   412
# 6    1.0    28    43     5   201
# 7    1.0    23    56     1   362
# 8    1.0    28    41     1   192
# 9    1.0    35    41     3   423

# %%
# 훈련
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # 훈련
# ----> 2 model = sm.OLS(y, X).fit()
#       3 print(model.summary())
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\regression\linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\regression\linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
#     745     weights = weights.squeeze()
# --> 746 super().__init__(endog, exog, missing=missing,
#     747                           weights=weights, hasconst=hasconst, **kwargs)
#     748 nobs = self.exog.shape[0]
#     749 weights = self.weights
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\regression\linear_model.py:200, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     199 def __init__(self, endog, exog, **kwargs):
# --> 200     super().__init__(endog, exog, **kwargs)
#     201     self.pinv_wexog: Float64Array | None = None
#     202     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\base\model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\base\model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\base\model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\base\data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\base\data.py:89, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      87 self.k_constant = 0
#      88 self._handle_constant(hasconst)
# ---> 89 self._check_integrity()
#      90 self._cache = {}
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\base\data.py:534, in PandasData._check_integrity(self)
#     530 if (exog is not None and
#     531         (hasattr(endog, 'index') and hasattr(exog, 'index')) and
#     532         not self.orig_endog.index.equals(self.orig_exog.index)):
#     533     raise ValueError("The indices for endog and exog are not aligned")
# --> 534 super()._check_integrity()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\statsmodels\base\data.py:436, in ModelData._check_integrity(self)
#     434 if self.exog is not None:
#     435     if len(self.exog) != len(self.endog):
# --> 436         raise ValueError("endog and exog matrices are different sizes")
#
# ValueError: endog and exog matrices are different sizes

# %% [markdown]
# 1차 분석 결과에서 yard는 p-value가 0.05 보다 컸기 때문에 분석에서 제외

# %%
X
# Out:
#    const  yard  area  park  dist
# 0    1.0    31    58     1   492
# 1    1.0    31    51     1   426
# 2    1.0    27    47     5   400
# 3    1.0    39    35     5   125
# 4    1.0    30    48     2   443
# 5    1.0    32    42     4   412
# 6    1.0    28    43     5   201
# 7    1.0    23    56     1   362
# 8    1.0    28    41     1   192
# 9    1.0    35    41     3   423

# %%
X2 = pd.DataFrame(dict(yard=yard, area=area, park=park, dist=dist))
X2 = X2[['area', 'park', 'dist']]
X2_const = sm.add_constant(X2)
X2_const
# Out:
#    const  area  park  dist
# 0    1.0    58     1   492
# 1    1.0    51     1   426
# 2    1.0    47     5   400
# 3    1.0    35     5   125
# 4    1.0    48     2   443
# 5    1.0    42     4   412
# 6    1.0    43     5   201
# 7    1.0    56     1   362
# 8    1.0    41     1   192
# 9    1.0    41     3   423

# %% [markdown]
# # 다중 회귀분석의 회귀식
# * y = (92.9476 * area) + (-14.4217 * dist) + 1.351e+04
# * 모델의 설명력은 R-squared가 아닌 Adj-R-squared를 봐야 함 0.680
# * 모델의 p-value: 0.00766이므로 0.05보다 작음

# %% [markdown]
# # 변수 선택
# * 전진선택법: 독립변수 0부터 시작해서 변수를 1개씩 추가
# * 후진제거법: 모든 독립변수를 다 포함 => 변수를 1개씩 삭제
# * 다중선택법: 전진 + 후진
# * AIC: 변수를 선택하는 지표

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

# %%
# 데이터 생성
yard = np.array([31, 31, 27, 39, 30, 32, 28, 23, 28, 35])
area = np.array([58, 51, 47, 35, 48, 42, 43, 56, 41, 41])
park = np.array([1, 1, 5, 5, 2, 4, 5, 1, 1, 3])
dist = np.array([492, 426, 400, 125, 443, 412, 201, 362, 192, 423])
popul = np.array([4412, 2061, 4407, 1933, 4029, 4180, 3444, 1683, 3020, 4459])
price = np.array([12631, 12084, 12220, 15649, 11486, 12276, 15527, 12666, 13180, 10169])

# 데이터프레임 생성
data = pd.DataFrame({'yard': yard, 'area': area, 'park': park, 'dist': dist, 'popul': popul, 'price': price})

# %%
data
# Out:
#    yard  area  park  dist  popul  price
# 0    31    58     1   492   4412  12631
# 1    31    51     1   426   2061  12084
# 2    27    47     5   400   4407  12220
# 3    39    35     5   125   1933  15649
# 4    30    48     2   443   4029  11486
# 5    32    42     4   412   4180  12276
# 6    28    43     5   201   3444  15527
# 7    23    56     1   362   1683  12666
# 8    28    41     1   192   3020  13180
# 9    35    41     3   423   4459  10169

# %%
# 독립변수와 종속변수 설정
X = data.drop('price', axis=1)
y = data['price']

# %%
X
# Out:
#    yard  area  park  dist  popul
# 0    31    58     1   492   4412
# 1    31    51     1   426   2061
# 2    27    47     5   400   4407
# 3    39    35     5   125   1933
# 4    30    48     2   443   4029
# 5    32    42     4   412   4180
# 6    28    43     5   201   3444
# 7    23    56     1   362   1683
# 8    28    41     1   192   3020
# 9    35    41     3   423   4459

# %%
y
# Out:
# 0    12631
# 1    12084
# 2    12220
# 3    15649
# 4    11486
# 5    12276
# 6    15527
# 7    12666
# 8    13180
# 9    10169
# Name: price, dtype: int64

# %%
# 전진 선택법을 사용한 회귀분석
model = LinearRegression()
sfs = SequentialFeatureSelector(model, direction='forward')
sfs.fit(X, y)

# 선택된 변수
selected_features = X.columns[sfs.get_support()]
selected_features
# Out:
# Index(['yard', 'park'], dtype='object')

# %%
# 최종 선택된 변수로 분석
X_selected = sm.add_constant(data[selected_features])
X_selected
# Out:
#    const  yard  park
# 0    1.0    31     1
# 1    1.0    31     1
# 2    1.0    27     5
# 3    1.0    39     5
# 4    1.0    30     2
# 5    1.0    32     4
# 6    1.0    28     5
# 7    1.0    23     1
# 8    1.0    28     1
# 9    1.0    35     3

# %%
final_model = sm.OLS(y, X_selected).fit()
print(final_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                 -0.036
# Method:                 Least Squares   F-statistic:                    0.8433
# Date:                Wed, 07 May 2025   Prob (F-statistic):              0.470
# Time:                        15:23:42   Log-Likelihood:                -86.871
# No. Observations:                  10   AIC:                             179.7
# Df Residuals:                       7   BIC:                             180.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.22e+04   3990.829      3.056      0.018    2758.393    2.16e+04
# yard         -19.4302    137.385     -0.141      0.892    -344.295     305.435
# park         422.9550    335.385      1.261      0.248    -370.105    1216.015
# ==============================================================================
# Omnibus:                        0.446   Durbin-Watson:                   2.392
# Prob(Omnibus):                  0.800   Jarque-Bera (JB):                0.503
# Skew:                          -0.245   Prob(JB):                        0.778
# Kurtosis:                       2.017   Cond. No.                         227.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\vbak0\miniforge3\envs\fintech\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   res = hypotest_fun_out(*samples, **kwds)
