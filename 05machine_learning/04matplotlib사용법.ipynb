# %% [markdown]
# # Matplotlib은 파이썬에서 그래프를 그릴 때 사용
# * pip install matplotlib, conda install matplotlib
# * pip install seaborn, conda install seaborn
# * pip install koreanize-matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import koreanize_matplotlib

# %% [markdown]
# # 간단한 그래프 예제

# %%
# 그래프를 그릴 도화지 준비
fig, ax = plt.subplots()

# 앞에가 X, 뒤에가 Y
ax.plot([1,2,3,4], [1,4,2,3])

plt.show()

# %% [markdown]
# * figure: 전체 그래프가 그려지는 도화지
# * axes: 한 칸에 그려지는 그래프
# * axis: 그래프의 X, Y 축 눈금

# %% [markdown]
# ## 그래프 없이 빈 도화지 만들기

# %%
fig = plt.figure()
plt.show()

# %% [markdown]
# ## x, y 축이 하나씩 있는 그래프 그리기

# %%
fig.ax = plt.subplots()
plt.show()

# %% [markdown]
# ## 2 x 2 4개 그래프 그리기

# %%
fig, ax = plt.subplots(2, 2)
print(ax.shape)
plt.show()
# Out:
# (2, 2)

# %% [markdown]
# ## 2 x 2 그래프에서 왼쪽 행 결합하기
# * subplot_mosaic([left, right], <br>
#                  [left, right])

# %%
fig, axes = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

plt.show()

# %%
fig, axes = plt.subplot_mosaic([['top', 'top'],
                               ['left', 'right']])

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 2.7))
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label = "quadratic")
ax.plot(x, x**3, label= "cubic")
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('간단 그래프')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 fig, ax = plt.subplots(figsize = (5, 2.7))
# ----> 2 ax.plot(x, x, label='linear')
#       3 ax.plot(x, x**2, label = "quadratic")
#       4 ax.plot(x, x**3, label= "cubic")
#
# NameError: name 'x' is not defined

# %% [markdown]
# # matplotlib의 2가지 코딩 스타일
# ##

# %% [markdown]
# ## pyplot 스타일
# * OO-style 보다 사용법 간단
# * 복잡한 그래프를 그릴 때는 적합하지 않다

# %%
plt.figure(figsize=(5, 2.7))
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel("X축 이름")
plt.ylabel("Y축 이름")
plt.title("pyplot 스타일 그래프")
plt.legend()
plt.show

# %% [markdown]
# # 선 모양 바꾸기 set_linestyle(모양)

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)

# %%
data1
# Out:
# array([-0.650142  ,  0.02595168,  0.48388321, -1.43254756, -0.78363997,
#         1.14600763,  1.32968809,  2.19997085,  0.47536554, -0.25219918,
#         0.27136257, -2.14213765, -0.24450269, -1.35048151,  0.52628912,
#        -0.33255605, -0.72782832,  0.00294005,  0.83221672, -0.21201039,
#         0.19158589,  2.0191447 , -0.10011141,  0.83955709,  0.30015605,
#        -0.07137171, -0.93395739,  0.58590303,  0.7710346 ,  0.23077637,
#        -0.29848933,  0.55813366,  0.79100478,  0.60703782, -0.24880958,
#         0.42273753, -0.48972829, -0.26642819,  0.5770995 , -1.76300528,
#         1.3518978 , -0.74113496, -0.2927426 ,  2.1065509 ,  0.26667169,
#        -1.14639465, -0.01976701,  1.19394139,  0.64227288,  0.63505426,
#         2.00996515,  0.42327346, -0.32410524, -0.76822062, -0.64772135,
#        -1.17677186, -0.3049267 , -0.89512577,  0.16096103, -0.57079082,
#        -1.02928045,  1.65503302, -1.5390734 , -0.11998923,  0.36896038,
#         0.37700096,  0.18194958,  0.61193074, -0.53789811,  1.8361656 ,
#        -0.55440495, -0.88155537, -0.10836238,  0.79992099, -0.2679773 ,
#        -0.99100992,  0.87290017, -1.03870077,  0.52876831, -0.25735896,
#        -0.57958334,  1.66551425, -0.49481443, -1.14428024, -0.42434554,
#         0.70507972, -1.49655307,  0.36848177,  0.29227766,  0.89655044,
#        -0.19716104,  0.67843201,  2.05593259,  0.0931227 ,  1.81413772,
#         0.0817644 ,  1.47312281, -0.0098923 , -0.06517878,  2.37172851])

# %% [markdown]
# * 선 모양: '-' , '--', '-.', ':', ''

# %%
len(data1)
# Out:
# 100

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle=":")
ax.plot(x, np.cumsum(data2), color='orange', linewidth=2, linestyle="-.")
plt.show()

# %% [markdown]
# # 산점도 그래프를 그리고 색 변경하기
# * facecolor(안쪽색), edgecolor(테두리색)

# %% [markdown]
# 컬러를 RGB 값으로 주고 싶으면 (0, 1, 0.5) 와 같이 0-1 사이 값을 주면 됨

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s= 50, facecolor=(0.5, 0.5, 0.5), edgecolor='k')
plt.show()

# %% [markdown]
# # 마커의 모양 지정하기

# %%
fig, ax = plt.subplot(figsize=(5, 2.7))
ax.plot(data1, 'o', label='data1')
ax.plot(data2, 'd', label='data2')
ax.plot(data3, 'v', label='data3')
ax.plot(data4, 's', label='data4')
ax.legend()
plt.show()

# %% [markdown]
# # X축, Y축 이름, 눈금, 그래프이름

# %%
#alpha 값은 투명도

mu, sigma = 115, 15
x = mu + sigma * np.random.rand(10000)
fig, ax = plt.subplots(figsize=(5, 2.7))
n, bins, patches = ax.hist(x, 50, density = True, facecolor = 'C0', alpha=0.75)
ax.set_xlabel("Length [cm]")
ax.set_ylabel("Probability")
ax.set_title('Aardvark lengths\n (not really)')
ax.text(75, .025, r'$\mu=115, \ \sigma=15$')
ax.axis([60, 160, 0, 0.03]) #x, y축의 범위
ax.axis([])
plt.show()

# %% [markdown]
# # 눈금자 단위 구간 설정하기

# %%
xdata = np.arange(len(data1))

fig, ax = plt.subplots(2, 1,figsize = (5, 2.7), layout = 'constrained')
ax[0].plot(xdata, data1)
ax[0].set_title('Automatic ticks')

ax[1].plot(xdata, data1)
ax[1].set_xticks(np.arange(0, 100, 30), ['zero', '30', 'sixty', '90'])
ax[1].set_yticks([-1.5, 0, 1.5])
ax[1].set_title("Manual ticks")
plt.show()

# %% [markdown]
# # 카테고리 막대 그래프 그리기

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
categories = ['turnips', 'rutabaga', 'cucumber', 'pumpkins']
ax.bar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 fig, ax = plt.subplots(figsize=(5, 2.7))
#       2 categories = ['turnips', 'rutabaga', 'cucumber', 'pumpkins']
# ----> 3 ax.bar()
#       4 plt.show()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\matplotlib\__init__.py:1476, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1473 @functools.wraps(func)
#    1474 def inner(ax, *args, data=None, **kwargs):
#    1475     if data is None:
# -> 1476         return func(
#    1477             ax,
#    1478             *map(sanitize_sequence, args),
#    1479             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1481     bound = new_sig.bind(ax, *args, **kwargs)
#    1482     auto_label = (bound.arguments.get(label_namer)
#    1483                   or bound.kwargs.get(label_namer))
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'
