# %% [markdown]
# ## h2
# # 세에에엘
# * 목록
#
# <h1>우땨땨</h1>
#   <li>울랄라</li>
#
# ** 굵게 만들기**
#
#
# ### 링크걸기
# [네이버링크](https://www.naver.com)
# [구글](https://www.google.com)
#
#
# ### 이미지 넣기
# ![%EB%82%98%EB%8B%88%EC%99%80%EB%8B%A8%EC%8B%9C.jpg](attachment:%EB%82%98%EB%8B%88%EC%99%80%EB%8B%A8%EC%8B%9C.jpg)

# %% [markdown]
# ## 수식 넣기
#
# $$ A \over B $$
# $$ (A \cap B) $$
#
#
# ## 실행키
# c + enter : 해당 코드만 실행 <br>
# ait + enter : 코드 실행 이후 아래 새로운 셀로 내려감 셀 실행 준비..<br>
# shift + enter : 아래 새로운 셀 이동만 함

# %% [markdown]
# **글자를 굵게 만들기** <br>
# *글자를 이탈릭체로 만들기* <br>
# <b>글자를 굵게 만들기<b> <br>
# <em>글자를 이탈릭체로 만들기<em>

# %% [markdown]
# * 목록1
#      * 목록 1
#      * 목록 2

# %% [markdown]
# [구글](https://www.google.com) <br>
# [문화 생활](https://www.postype.com)
